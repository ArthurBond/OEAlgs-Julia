# %%
np.where(alloc_exp_p_temp < 0)[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 np.where(alloc_exp_p_temp < 0)[0]
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
alloc_exp_p_temp = [1,2,3,4,-1]

# %%
import numpy as np

# %%
np.where(np.array(lst) < 0,0,lst)
# Out:
# array([1, 2, 3, 4, 0])

# %%
[1,2,3,4,-1] < 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 [1,2,3,4,-1] < 0
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuration variables
filename = "NODELAY.bin"  # Replace with your file's name
adc_resolution = 12        # Set according to your ADC resolution (e.g., 12 for a 12-bit ADC)
vref = 5                 # Reference voltage for the ADC

# Calculate the maximum possible ADC value based on the resolution
max_adc_value = (2 ** adc_resolution) - 1

# Read ADC values from the binary file
with open(filename, "rb") as file:
    # Assuming 32-bit unsigned integers are stored, you can adjust this to your data format
    adc_values = np.fromfile(file,dtype=np.uint32)

# Convert ADC values to voltage
voltages = adc_values / max_adc_value * vref

# voltages = adc_values

# Plot the waveform using matplotlib
plt.figure(figsize=(20,1))
# plt.scatter(list(range(len(voltages))),voltages, label="Waveform")
plt.plot(voltages[:int(len(voltages)/10)], label="Waveform")
plt.title("Waveform from ADC Data")
plt.xlabel("Sample Number")
plt.ylabel("Voltage (V)")
plt.legend()
plt.grid(True)
plt.show()

# %%
import os

# %%
np.savetxt("foo.csv", adc_values, delimiter=",")

# %%
min(adc_values)
# Out:
# 32
